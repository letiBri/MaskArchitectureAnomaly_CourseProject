# %% [markdown]
# <a href="https://colab.research.google.com/github/letiBri/MaskArchitectureAnomaly_CourseProject/blob/main/eomt/STEP5_NUOVO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# © 2025 Mobile Perception Systems Lab at TU/e. All rights reserved. Licensed under the MIT License.

# %%
# !git clone https://github.com/letiBri/MaskArchitectureAnomaly_CourseProject.git

# %cd MaskArchitectureAnomaly_CourseProject/eomt
# Out:
# Cloning into 'MaskArchitectureAnomaly_CourseProject'...
# remote: Enumerating objects: 428, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 428 (delta 17), reused 0 (delta 0), pack-reused 398 (from 2)
# Receiving objects: 100% (428/428), 30.79 MiB | 21.73 MiB/s, done.
# Resolving deltas: 100% (168/168), done.
# /content/MaskArchitectureAnomaly_CourseProject/eomt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys # Allows importing from the 'eomt' folder
sys.path.append('/content/MaskArchitectureAnomaly_CourseProject')
sys.path.append('/content/MaskArchitectureAnomaly_CourseProject/eomt')

# %%
# !python3 -m pip install -r requirements.txt
# Out:
# Collecting gitignore_parser==0.1.12 (from -r requirements.txt (line 1))
#   Downloading gitignore_parser-0.1.12.tar.gz (5.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jsonargparse==4.38 (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2))
#   Downloading jsonargparse-4.38.0-py3-none-any.whl.metadata (12 kB)
# Collecting matplotlib==3.10.1 (from -r requirements.txt (line 3))
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting timm==1.0.15 (from -r requirements.txt (line 4))
#   Downloading timm-1.0.15-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.2 MB/s eta 0:00:00
# Collecting wandb==0.19.10 (from -r requirements.txt (line 5))
#   Downloading wandb-0.19.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting lightning==2.5.1.post0 (from -r requirements.txt (line 6))
#   Downloading lightning-2.5.1.post0-py3-none-any.whl.metadata (39 kB)
# Collecting transformers==4.56.1 (from -r requirements.txt (line 7))
#   Downloading transformers-4.56.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.6 MB/s eta 0:00:00
# Collecting scipy==1.15.2 (from -r requirements.txt (line 8))
#   Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.2 MB/s eta 0:00:00
# Collecting torch==2.7.0 (from -r requirements.txt (line 9))
#   Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision==0.22.0 (from -r requirements.txt (line 10))
#   Downloading torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting ipykernel==6.29.5 (from -r requirements.txt (line 11))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting fvcore==0.1.5.post20221221 (from -r requirements.txt (line 12))
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torchmetrics==1.7.1 (from -r requirements.txt (line 13))
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting pycocotools==2.0.8 (from -r requirements.txt (line 14))
#   Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from jsonargparse==4.38->jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm==1.0.15->-r requirements.txt (line 4)) (1.11.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm==1.0.15->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (8.3.3)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.19.10->-r requirements.txt (line 5))
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (4.9.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (5.29.6)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (2.12.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (2.58.0)
# Collecting setproctitle (from wandb==0.19.10->-r requirements.txt (line 5))
#   Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.12/dist-packages (from wandb==0.19.10->-r requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning==2.5.1.post0->-r requirements.txt (line 6))
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting packaging>=20.0 (from matplotlib==3.10.1->-r requirements.txt (line 3))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning==2.5.1.post0->-r requirements.txt (line 6)) (4.67.3)
# Collecting pytorch-lightning (from lightning==2.5.1.post0->-r requirements.txt (line 6))
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 7)) (3.29.0)
# Collecting huggingface_hub (from timm==1.0.15->-r requirements.txt (line 4))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 7)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.1->-r requirements.txt (line 7)) (0.22.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 9)) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 9)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.0->-r requirements.txt (line 9)) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch==2.7.0->-r requirements.txt (line 9))
#   Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting comm>=0.1.1 (from ipykernel==6.29.5->-r requirements.txt (line 11))
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r requirements.txt (line 11)) (5.7.1)
# Collecting yacs>=0.1.6 (from fvcore==0.1.5.post20221221->-r requirements.txt (line 12))
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore==0.1.5.post20221221->-r requirements.txt (line 12)) (3.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore==0.1.5.post20221221->-r requirements.txt (line 12)) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.5.post20221221->-r requirements.txt (line 12))
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 896.6 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (0.18.0)
# Collecting typeshed-client>=2.1.0 (from jsonargparse[signatures]==4.38->-r requirements.txt (line 2))
#   Downloading typeshed_client-2.11.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.19.10->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (3.13.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm==1.0.15->-r requirements.txt (line 4)) (1.4.3)
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.5.post20221221->-r requirements.txt (line 12))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.19.10->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.19.10->-r requirements.txt (line 5)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb==0.19.10->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.7.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.1.0->jsonargparse[signatures]==4.38->-r requirements.txt (line 2)) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.7.0->-r requirements.txt (line 9)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning==2.5.1.post0->-r requirements.txt (line 6)) (1.23.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.10->-r requirements.txt (line 5)) (5.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==6.29.5->-r requirements.txt (line 11)) (0.6.0)
# Downloading jsonargparse-4.38.0-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 9.7 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 83.6 MB/s eta 0:00:00
# Downloading timm-1.0.15-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 98.3 MB/s eta 0:00:00
# Downloading wandb-0.19.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 66.8 MB/s eta 0:00:00
# Downloading lightning-2.5.1.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 41.7 MB/s eta 0:00:00
# Downloading transformers-4.56.1-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 88.7 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 23.2 MB/s eta 0:00:00
# Downloading torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.0/865.0 MB 1.2 MB/s eta 0:00:00
# Downloading torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 97.5 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 11.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 64.2 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 43.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 91.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 50.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 69.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 8.6 MB/s eta 0:00:00
# Downloading triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 MB 6.7 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 45.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.7 MB/s eta 0:00:00
# Downloading typeshed_client-2.11.0-py3-none-any.whl (787 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787.6/787.6 kB 49.8 MB/s eta 0:00:00
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 47.8 MB/s eta 0:00:00
# Downloading setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 121.4 MB/s eta 0:00:00
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: gitignore_parser, fvcore, iopath
#   Building wheel for gitignore_parser (pyproject.toml) ... done
#   Created wheel for gitignore_parser: filename=gitignore_parser-0.1.12-py3-none-any.whl size=5054 sha256=0523df6b6e226f3e10d3edc7482ab6bd2f7d13d7c0fba26394cd85b663be43cd
#   Stored in directory: /root/.cache/pip/wheels/2e/1e/fd/5f54a9fb2812e64c709303dab7d79ef5e74a655a0dcad67b91
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=f5f392a1279631194965c88df0e6297fc9a5d1dac1f71e6eeb09f0dcdb37f5d6
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=49c218856b82d02acf82a0270ff546bb40ffd047be81fc06fda1b0cdb7646984
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built gitignore_parser fvcore iopath
# Installing collected packages: nvidia-cusparselt-cu12, gitignore_parser, yacs, typeshed-client, triton, setproctitle, scipy, portalocker, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jsonargparse, jedi, docker-pycreds, comm, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, matplotlib, lightning-utilities, iopath, huggingface_hub, wandb, pycocotools, nvidia-cusolver-cu12, ipykernel, fvcore, transformers, torch, torchvision, torchmetrics, timm, pytorch-lightning, lightning
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.1
#     Uninstalling packaging-26.1:
#       Successfully uninstalled packaging-26.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.26.1
#     Uninstalling wandb-0.26.1:
#       Successfully uninstalled wandb-0.26.1
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.11
#     Uninstalling pycocotools-2.0.11:
#       Successfully uninstalled pycocotools-2.0.11
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.10.0+cu128
#     Uninstalling torch-2.10.0+cu128:
#       Successfully uninstalled torch-2.10.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.25.0+cu128
#     Uninstalling torchvision-0.25.0+cu128:
#       Successfully uninstalled torchvision-0.25.0+cu128
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.26
#     Uninstalling timm-1.0.26:
#       Successfully uninstalled timm-1.0.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.7.0 which is incompatible.
# Successfully installed comm-0.2.3 docker-pycreds-0.4.0 fvcore-0.1.5.post20221221 gitignore_parser-0.1.12 huggingface_hub-0.36.2 iopath-0.1.10 ipykernel-6.29.5 jedi-0.20.0 jsonargparse-4.38.0 lightning-2.5.1.post0 lightning-utilities-0.15.3 matplotlib-3.10.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 packaging-24.2 portalocker-3.2.0 pycocotools-2.0.8 pytorch-lightning-2.6.1 scipy-1.15.2 setproctitle-1.3.7 timm-1.0.15 torch-2.7.0 torchmetrics-1.7.1 torchvision-0.22.0 transformers-4.56.1 triton-3.3.0 typeshed-client-2.11.0 wandb-0.19.10 yacs-0.1.8

# %%
# !pip uninstall -y wandb
# !pip install -U wandb

import wandb
from lightning.pytorch.loggers import WandbLogger

wandb.login()

wandb_logger = WandbLogger(project="cityscapes_finetuning", # Crea (o seleziona, se esiste già) una cartella macro chiamata progetto sul tuo profilo online. Tutti i tentativi e i test correlati a questo lavoro verranno raggruppati qui dentro
                           name="finetune_selective_run", # Assegna un nome specifico a questa esecuzione (es. eomt_baseline_run). Ti permette di distinguere questo addestramento dai futuri test (magari con iperparametri diversi).
                           log_model = False # Impedisce a WandB di caricare i file pesanti dei pesi del modello (.ckpt o .bin) sui loro server cloud alla fine di ogni epoca. Salva direttamente sul tuo Google Drive tramite il ModelCheckpoint, risparmiando banda internet e spazio cloud gratuito su WandB.
                           )
# Out:
# Found existing installation: wandb 0.19.10
# Uninstalling wandb-0.19.10:
#   Successfully uninstalled wandb-0.19.10
# Collecting wandb
#   Downloading wandb-0.27.0-py3-none-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.47)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (24.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.6)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2026.4.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.3)
# Downloading wandb-0.27.0-py3-none-manylinux_2_28_x86_64.whl (27.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 25.4 MB/s eta 0:00:00
# Installing collected packages: wandb
# Successfully installed wandb-0.27.0
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: giuliadesantis (giuliadesantis-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Setup

# %%
import yaml
import torch
import importlib
import logging
import lightning as L
import matplotlib.pyplot as plt
import numpy as np
import warnings

from lightning import seed_everything
from torch.nn import functional as F
from torch.amp.autocast_mode import autocast
from huggingface_hub import hf_hub_download
from huggingface_hub.utils import RepositoryNotFoundError
from lightning.pytorch.callbacks import ModelCheckpoint

seed_everything(0, verbose=False)

device = 0  # TODO: change to the GPU you want to use
IGNORE_INDEX = 255
img_idx = 10  # TODO: change to the index of the image you want to visualize
data_path = "/content/drive/MyDrive/CourseProjectAnomaly"  # drive folder of the cityscapes val set

def create_mapping(images, ignore_index):
    unique_ids = np.unique(np.concatenate([np.unique(img) for img in images]))
    valid_ids = unique_ids[unique_ids != ignore_index]
    colors = np.array(
        [plt.cm.hsv(i / len(valid_ids))[:3] for i in range(len(valid_ids))]
    )
    mapping = {cid: colors[i] for i, cid in enumerate(valid_ids)}
    mapping[ignore_index] = np.array([0, 0, 0])
    return mapping


def apply_colormap(image, mapping):
    colored_image = np.zeros((*image.shape, 3))
    for cid in np.unique(image):
        colored_image[image == cid] = mapping.get(cid, [0, 0, 0])
    return colored_image

# %% [markdown]
# ## Load dataset
#
# Ensure the dataset files are correctly prepared and placed in the folder specified by `data_path`.

# %%
state_dict_path = "/content/drive/MyDrive/CourseProjectAnomaly/eomt_coco.bin" # punta ai pesi pre-addestrati su COCO
config_path = "configs/dinov2/cityscapes/semantic/eomt_base_640.yaml"

with open(config_path, "r") as f:
    config_cs = yaml.safe_load(f)

target_img_size = (640, 640)
num_classes_final = 19  # classi di cityscapes

data_module_name, class_name = config_cs["data"]["class_path"].rsplit(".", 1)
data_module = getattr(importlib.import_module(data_module_name), class_name)
data_module_kwargs = config_cs["data"].get("init_args", {})

data = data_module(
    path=data_path,
    batch_size=2,
    num_workers=2,
    check_empty_targets=True,
    img_size = target_img_size,
    **data_module_kwargs
)
data.setup()

# %%
# PARTE NUOVA

# %%
# 1. Setup Network (FORZA query a 200 per compatibilità COCO)
net_cfg = config_cs["model"]["init_args"]["network"]
encoder_cfg = net_cfg["init_args"]["encoder"]

# Inizializza Encoder
enc_mod, enc_cls = encoder_cfg["class_path"].rsplit(".", 1)
encoder = getattr(importlib.import_module(enc_mod), enc_cls)(img_size=(640,640), **encoder_cfg.get("init_args", {}))

# Inizializza Network (EoMT)
net_mod, net_cls = net_cfg["class_path"].rsplit(".", 1)
network = getattr(importlib.import_module(net_mod), net_cls)(
    masked_attn_enabled=True, #MODIFICATO
    num_classes=19, # Cityscapes
    encoder=encoder,
    num_q=200,      # Fondamentale: deve matchare i pesi COCO
    num_blocks=3
)

# 2. Setup Lightning Module
lit_mod, lit_cls = config_cs["model"]["class_path"].rsplit(".", 1)
# model = getattr(importlib.import_module(lit_mod), lit_cls)(
#     network=network,
#     img_size=(640,640),
#     num_classes=19,
#     ckpt_path=state_dict_path,
#     load_ckpt_class_head=False, # Reinizializza la testa da zero
#     lr=5e-5,
#     llrd=0.9,
#     llrd_l2_enabled=False,
#     lr_mult=1.0,
#     weight_decay=0.05,
#     poly_power=0.9,
#     warmup_steps=(0, 0),
#     attn_mask_annealing_enabled=False,
#     attn_mask_annealing_start_steps=None,
#     attn_mask_annealing_end_steps=None
# ).to(device)

model_kwargs_final = {k: v for k, v in config_cs["model"]["init_args"].items() if k != "network"}
model_kwargs_final.pop("num_classes", None)
model_kwargs_final.pop("img_size", None)

model = getattr(importlib.import_module(lit_mod), lit_cls)(
          img_size=target_img_size,
          num_classes=num_classes_final,
          network=network,
          **model_kwargs_final,
          ckpt_path=state_dict_path,          # Serve alla TUA classe per caricare il .bin iniziale
          load_ckpt_class_head=False
      ).to(device)

#print(model)




# 3. FREEZING SELETTIVO
for param in model.parameters():
    param.requires_grad = False

# Sblocca Testa + Ultimo Blocco Decoder
layers_to_train = ["class_head", #sblocco la testa --> Impara i nomi delle 19 classi di Cityscapes
                   #"mask_head", #--> Impara le geometrie e i contorni degli oggetti stradali
                   #"network.upscale", #--> Adatta la risoluzione spaziale alle immagini urbane
                   ]
for name, param in model.named_parameters():
    if any(k in name for k in layers_to_train):
        param.requires_grad = True
        print(f"SBLOCCATO: {name}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'network' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['network'])`.
# SBLOCCATO: network.class_head.weight
# SBLOCCATO: network.class_head.bias

# %% [markdown]
# 1. Il blocco del trasferimento (Caricamento e Reset)ckpt_path=state_dict_path: Indica al modulo dove trovare il file .bin (o .ckpt) contenente i pesi pre-addestrati su COCO. Senza questo, il modello partirebbe con pesi casuali, ignorando tutto ciò che sa già sulla struttura del mondo visivo.load_ckpt_class_head=False: È il parametro più importante di tutti. Dice al sistema: "Carica tutto il modello da COCO, ma scarta lo strato finale che classificava i vecchi oggetti (come divani, pizze o animali) e creane uno nuovo di zecca, inizializzato da zero". Sarà questa nuova testa a imparare le 19 classi urbane di Cityscapes.
#
# 2. Ottimizzazione e Controllo del Gradiente (LLRD)Il modello utilizza una tecnica avanzata chiamata LLRD (Layer-wise Learning Rate Decay), molto comune quando si fa fine-tuning su modelli basati su Transformer (come il tuo encoder ViT).llrd=0.9 e lr_mult=1.0: Questa logica dice che i layer più vicini all'input (i primi blocchi dell'encoder) dovrebbero aggiornarsi molto meno (o per nulla) rispetto ai layer finali. Poiché i primi layer estraggono feature universali (bordi, linee, colori), non vogliamo che cambino bruscamente.lr=5e-5 (Learning Rate): È un valore decisamente basso ($0.00005$). Nel fine-tuning non si usano mai learning rate alti (come 1e-3), altrimenti i passi dell'ottimizzatore sarebbero troppo grandi e finirebbero per distruggere brutalmente la conoscenza pregressa memorizzata nei pesi presi da COCO.
#
# 3. Regolarizzazione e Stabilitàweight_decay=0.05: Applica una penalità ai pesi troppo grandi (regolarizzazione L2). Aiuta a prevenire l'overfitting, costringendo il modello a rimanere flessibile ed evitando che si concentri troppo sui dettagli microscopici delle poche immagini di addestramento che gli stai fornendo.poly_power=0.9: Configura un decadimento polinomiale del learning rate. Significa che il tasso di apprendimento decrescerà lentamente man mano che le epoche avanzano, permettendo al modello di fare grandi passi all'inizio e piccoli aggiustamenti di precisione verso la fine del training.
#
# 4. Disattivazione dei meccanismi non necessariI parametri impostati a False o None (come warmup_steps=(0, 0) e attn_mask_annealing_enabled=False) servono a disattivare le funzioni di addestramento da zero.L'annealing delle maschere di attenzione e il warmup del learning rate sono tecniche usate nelle prime fasi di vita di un modello per evitare che i gradienti esplodano quando la rete non sa ancora fare nulla. Dato che il tuo modello ha già alle spalle un solido addestramento su COCO, queste precauzioni non sono più necessarie e rallenterebbero solo la convergenza su Cityscapes.

# %%
print(model)
# Out:
# MaskClassificationSemantic(
#   (network): EoMT(
#     (encoder): ViT(
#       (backbone): VisionTransformer(
#         (patch_embed): PatchEmbed(
#           (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#           (norm): Identity()
#         )
#         (pos_drop): Dropout(p=0.0, inplace=False)
#         (patch_drop): Identity()
#         (norm_pre): Identity()
#         (blocks): Sequential(
#           (0): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (1): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (2): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (3): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (4): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (5): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (6): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (7): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (8): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (9): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (10): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#           (11): Block(
#             (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (attn): Attention(
#               (qkv): Linear(in_features=768, out_features=2304, bias=True)
#               (q_norm): Identity()
#               (k_norm): Identity()
#               (attn_drop): Dropout(p=0.0, inplace=False)
#               (proj): Linear(in_features=768, out_features=768, bias=True)
#               (proj_drop): Dropout(p=0.0, inplace=False)
#             )
#             (ls1): LayerScale()
#             (drop_path1): Identity()
#             (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#             (mlp): Mlp(
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (act): GELU(approximate='none')
#               (drop1): Dropout(p=0.0, inplace=False)
#               (norm): Identity()
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (drop2): Dropout(p=0.0, inplace=False)
#             )
#             (ls2): LayerScale()
#             (drop_path2): Identity()
#           )
#         )
#         (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (fc_norm): Identity()
#         (head_drop): Dropout(p=0.0, inplace=False)
#         (head): Identity()
#       )
#     )
#     (q): Embedding(200, 768)
#     (class_head): Linear(in_features=768, out_features=20, bias=True)
#     (mask_head): Sequential(
#       (0): Linear(in_features=768, out_features=768, bias=True)
#       (1): GELU(approximate='none')
#       (2): Linear(in_features=768, out_features=768, bias=True)
#       (3): GELU(approximate='none')
#       (4): Linear(in_features=768, out_features=768, bias=True)
#     )
#     (upscale): Sequential(
#       (0): ScaleBlock(
#         (conv1): ConvTranspose2d(768, 768, kernel_size=(2, 2), stride=(2, 2))
#         (act): GELU(approximate='none')
#         (conv2): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#         (norm): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): ScaleBlock(
#         (conv1): ConvTranspose2d(768, 768, kernel_size=(2, 2), stride=(2, 2))
#         (act): GELU(approximate='none')
#         (conv2): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#         (norm): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (criterion): MaskClassificationLoss(
#     (matcher): Mask2FormerHungarianMatcher()
#   )
#   (metrics): ModuleList(
#     (0-3): 4 x MulticlassJaccardIndex()
#   )
# )

# %%
# Stampa il nome di OGNI layer e se è congelato (False) o sbloccato (True)
for name, param in model.named_parameters():
    print(f"{name:<60} | Richiede Gradiente: {param.requires_grad}")
# Out:
# network.encoder.backbone.cls_token                           | Richiede Gradiente: False
# network.encoder.backbone.reg_token                           | Richiede Gradiente: False
# network.encoder.backbone.pos_embed                           | Richiede Gradiente: False
# network.encoder.backbone.patch_embed.proj.weight             | Richiede Gradiente: False
# network.encoder.backbone.patch_embed.proj.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.0.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.1.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.2.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.3.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.4.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.5.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.6.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.7.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.8.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.norm1.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.norm1.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.attn.qkv.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.attn.qkv.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.attn.proj.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.attn.proj.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.ls1.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.norm2.weight               | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.norm2.bias                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.mlp.fc1.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.mlp.fc1.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.mlp.fc2.weight             | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.mlp.fc2.bias               | Richiede Gradiente: False
# network.encoder.backbone.blocks.9.ls2.gamma                  | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.norm1.weight              | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.norm1.bias                | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.attn.qkv.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.attn.qkv.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.attn.proj.weight          | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.attn.proj.bias            | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.ls1.gamma                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.norm2.weight              | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.norm2.bias                | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.mlp.fc1.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.mlp.fc1.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.mlp.fc2.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.mlp.fc2.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.10.ls2.gamma                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.norm1.weight              | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.norm1.bias                | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.attn.qkv.weight           | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.attn.qkv.bias             | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.attn.proj.weight          | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.attn.proj.bias            | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.ls1.gamma                 | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.norm2.weight              | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.norm2.bias                | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.mlp.fc1.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.mlp.fc1.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.mlp.fc2.weight            | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.mlp.fc2.bias              | Richiede Gradiente: False
# network.encoder.backbone.blocks.11.ls2.gamma                 | Richiede Gradiente: False
# network.encoder.backbone.norm.weight                         | Richiede Gradiente: False
# network.encoder.backbone.norm.bias                           | Richiede Gradiente: False
# network.q.weight                                             | Richiede Gradiente: False
# network.class_head.weight                                    | Richiede Gradiente: True
# network.class_head.bias                                      | Richiede Gradiente: True
# network.mask_head.0.weight                                   | Richiede Gradiente: False
# network.mask_head.0.bias                                     | Richiede Gradiente: False
# network.mask_head.2.weight                                   | Richiede Gradiente: False
# network.mask_head.2.bias                                     | Richiede Gradiente: False
# network.mask_head.4.weight                                   | Richiede Gradiente: False
# network.mask_head.4.bias                                     | Richiede Gradiente: False
# network.upscale.0.conv1.weight                               | Richiede Gradiente: False
# network.upscale.0.conv1.bias                                 | Richiede Gradiente: False
# network.upscale.0.conv2.weight                               | Richiede Gradiente: False
# network.upscale.0.norm.weight                                | Richiede Gradiente: False
# network.upscale.0.norm.bias                                  | Richiede Gradiente: False
# network.upscale.1.conv1.weight                               | Richiede Gradiente: False
# network.upscale.1.conv1.bias                                 | Richiede Gradiente: False
# network.upscale.1.conv2.weight                               | Richiede Gradiente: False
# network.upscale.1.norm.weight                                | Richiede Gradiente: False
# network.upscale.1.norm.bias                                  | Richiede Gradiente: False

# %% [markdown]
# # Transfer Learning and Fine Tuning

# %%
from lightning.pytorch.callbacks import ModelCheckpoint

# 1. Definiamo il Checkpoint Callback
checkpoint_callback = ModelCheckpoint(
    dirpath="/content/drive/MyDrive/CourseProjectAnomaly/checkpoints", # Dove salvare
    filename="eomt-cityscapes-finetuning-{epoch:02d}-{metrics/val_iou_all:.3f}",
    monitor="metrics/val_iou_all", # La metrica da monitorare
    mode="max",                    # Vogliamo massimizzare la IoU
    save_top_k=1,                  # Salva solo il file migliore in assoluto
    save_last = True,
    verbose=True                   # ??
)

current_max_epochs = 3
use_checkpoint = False ##########################################
resume_ckpt_path = "/content/drive/MyDrive/CourseProjectAnomaly/checkpoints/last-v1.ckpt"


# 2. Configuriamo il Trainer includendo il callback e il logger
trainer = L.Trainer(
    max_epochs=current_max_epochs,
    accelerator="gpu",
    devices=1,
    precision="16-mixed",
    logger=wandb_logger,          # Fondamentale per vedere i grafici
    callbacks=[checkpoint_callback], # Colleghiamo il salvataggio automatico

    limit_train_batches=0.01,      # Opzionale: per test rapidi
    limit_val_batches=0.01,        # Valida solo sul 5%

    log_every_n_steps=10,
    default_root_dir="/content/drive/MyDrive/CourseProjectAnomaly/checkpoints"
)

# 3. Avvio Training (GESTIONE DEL CHECKPOINT)
if use_checkpoint:
  print(f"Ripresa dell'addestramento dal checkpoint: {resume_ckpt_path}")
  trainer.fit(model, datamodule=data, ckpt_path=resume_ckpt_path)
else:
  trainer.fit(model, datamodule=data)

# 4. Dopo il training, stampa dove si trova il file migliore
print(f"Miglior modello salvato in: {checkpoint_callback.best_model_path}")
print(f"Miglior mIoU raggiunta: {checkpoint_callback.best_model_score:.4f}")
# Out:
# INFO: Using 16bit Automatic Mixed Precision (AMP)
# INFO:lightning.pytorch.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>wandb/run-20260518_170839-0zpmfmfp</code>
# Syncing run <strong><a href='https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning/runs/0zpmfmfp' target="_blank">finetune_selective_run</a></strong> to <a href='https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning' target="_blank">https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning</a>
#  View run at <a href='https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning/runs/0zpmfmfp' target="_blank">https://wandb.ai/giuliadesantis-politecnico-di-torino/cityscapes_finetuning/runs/0zpmfmfp</a>
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO: Loading `train_dataloader` to estimate number of stepping batches.
# INFO:lightning.pytorch.utilities.rank_zero:Loading `train_dataloader` to estimate number of stepping batches.
# INFO:
#   | Name      | Type                   | Params | Mode
# -------------------------------------------------------------
# 0 | network   | EoMT                   | 93.6 M | train
# 1 | criterion | MaskClassificationLoss | 0      | train
# 2 | metrics   | ModuleList             | 0      | train
# -------------------------------------------------------------
# 15.4 K    Trainable params
# 93.6 M    Non-trainable params
# 93.6 M    Total params
# 374.302   Total estimated model params size (MB)
# 292       Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name      | Type                   | Params | Mode
# -------------------------------------------------------------
# 0 | network   | EoMT                   | 93.6 M | train
# 1 | criterion | MaskClassificationLoss | 0      | train
# 2 | metrics   | ModuleList             | 0      | train
# -------------------------------------------------------------
# 15.4 K    Trainable params
# 93.6 M    Non-trainable params
# 93.6 M    Total params
# 374.302   Total estimated model params size (MB)
# 292       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: mIoU: 0.3
# INFO:lightning.pytorch.utilities.rank_zero:mIoU: 0.3
# INFO: Epoch 0, global step 14: 'metrics/val_iou_all' reached 0.00291 (best 0.00291), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=00-metrics/val_iou_all=0.003.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 14: 'metrics/val_iou_all' reached 0.00291 (best 0.00291), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=00-metrics/val_iou_all=0.003.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: mIoU: 0.3
# INFO:lightning.pytorch.utilities.rank_zero:mIoU: 0.3
# INFO: Epoch 1, global step 28: 'metrics/val_iou_all' reached 0.00317 (best 0.00317), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=01-metrics/val_iou_all=0.003.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 28: 'metrics/val_iou_all' reached 0.00317 (best 0.00317), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=01-metrics/val_iou_all=0.003.ckpt' as top 1
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: mIoU: 0.4
# INFO:lightning.pytorch.utilities.rank_zero:mIoU: 0.4
# INFO: Epoch 2, global step 42: 'metrics/val_iou_all' reached 0.00353 (best 0.00353), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=02-metrics/val_iou_all=0.004.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 42: 'metrics/val_iou_all' reached 0.00353 (best 0.00353), saving model to '/content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=02-metrics/val_iou_all=0.004.ckpt' as top 1
# INFO: `Trainer.fit` stopped: `max_epochs=3` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=3` reached.
# Miglior modello salvato in: /content/drive/.shortcut-targets-by-id/1anujPehiSRqow-CwUA580wxEa24htbA1/CourseProjectAnomaly/checkpoints/eomt-cityscapes-finetuning-epoch=02-metrics/val_iou_all=0.004.ckpt
# Miglior mIoU raggiunta: 0.0035

# %%
def infer_semantic(img, target, model, target_size=(640, 640)):
    """
    Esegue l'inferenza semantica con sliding window.
    """
    model.eval()
    # Convert the image to float and move to device
    img = img.float().to(device)

    # Cruciale: impostiamo la dimensione della finestra del modello
    model.window_size = target_size[0]

    with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
        imgs = [img]
        img_sizes = [img.shape[-2:]]

        # Divisione in finestre (sliding window) per gestire alta risoluzione
        crops, origins = model.window_imgs_semantic(imgs)

        # Forward pass (restituisce liste di logit per ogni layer)
        mask_logits_layers, class_logits_layers = model(crops)

        # Prendiamo l'output dell'ultimo blocco del decoder
        m_logits = F.interpolate(mask_logits_layers[-1], target_size, mode="bilinear")
        c_logits = class_layers = class_logits_layers[-1]

        # Conversione query-mask -> pixel-logits
        crop_pixel_logits = model.to_per_pixel_logits_semantic(m_logits, c_logits)

        # Ricomposizione dell'immagine originale dalle finestre
        full_logits = model.revert_window_logits_semantic(crop_pixel_logits, origins, img_sizes)

        # Selezione della classe dominante per ogni pixel
        preds = full_logits[0].argmax(0).cpu().numpy()

    # Conversione del Ground Truth per il confronto
    target_pixel = model.to_per_pixel_targets_semantic([target], IGNORE_INDEX)[0].numpy()

    return preds, target_pixel


def plot_semantic_results(img, pred_array, target_array):
    mapping = create_mapping([pred_array, target_array], IGNORE_INDEX)

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # Gestione dell'immagine (se normalizzata o meno)
    img_np = img.permute(1, 2, 0).cpu().numpy()
    # Se i valori sono fuori dal range [0,1], normalizziamo per la visualizzazione
    if img_np.max() > 1.0 or img_np.min() < 0:
        img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())

    axes[0].imshow(img_np) # Ora usiamo l'immagine processata
    axes[0].set_title("Original Image")

    # 2. Applica la colormap alla predizione
    axes[1].imshow(apply_colormap(pred_array, mapping))
    axes[1].set_title("Model Prediction")

    # 3. Applica la colormap al target (Ground Truth)
    axes[2].imshow(apply_colormap(target_array, mapping))
    axes[2].set_title("Ground Truth")

    for ax in axes:
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %%
# # 1. Recupera l'immagine e il target dal dataset di validazione di Cityscapes
# img_cs, target_cs = data.val_dataloader().dataset[img_idx]

# # 2. Esegui l'inferenza passandogli esplicitamente il modello e la dimensione target
# # Nota: abbiamo aggiunto 'model' e 'target_img_size' agli argomenti
# pred_array_cs, target_array_cs = infer_semantic(img_cs, target_cs, model, target_size=target_img_size)

# # 3. Visualizza i risultati (Immagine, Predizione, Ground Truth)
# plot_semantic_results(img_cs, pred_array_cs, target_array_cs)

# %% [markdown]
# # Evaluation

# %%
# # nuovo codice

# import numpy as np
# import torch
# import gc
# from tqdm import tqdm


# def fast_hist(a, b, n):
#   k = (a >= 0) & (a < n) & (b >= 0) & (b < n)
#   return np.bincount(n * a[k].astype(int) + b[k], minlength=n**2).reshape(n, n)

# def per_class_iu(hist):
#   return np.diag(hist) / (np.maximum(1.0, hist.sum(1) + hist.sum(0) - np.diag(hist)))


# # =====================================================================
# # 1. SETUP DELLE MATRICI DI CONFUSIONE E DEI MODELLI
# # =====================================================================
# num_eval_classes = 19
# val_loader = data.val_dataloader()

# # Creiamo due matrici di confusione separate per accumulare i dati
# hist_coco = np.zeros((num_eval_classes, num_eval_classes))
# hist_finetuned = np.zeros((num_eval_classes, num_eval_classes))

# # --- STEP A: VALUTAZIONE CON IL MODELLO FINE-TUNED ---
# # Il modello attualmente in memoria (model) è quello appena addestrato.
# # Eseguiamo prima la valutazione su di lui per sfruttare i pesi già caricati.
# print(f"📊 Fase 1: Valutazione in corso con il modello FINE-TUNED su {len(val_loader.dataset)} immagini...")

# model.eval() # <--- Regola il COMPORTAMENTO dei layer (spegne Dropout/Norm)
# with torch.no_grad(): # <--- Regola la MEMORIA (disattiva il calcolo dei gradienti)
#     for batch in tqdm(val_loader, desc="Fine-tuned Evaluation"):
#         imgs, targets = batch

#         for j in range(imgs.shape[0]):
#             # Inferenza con il modello Fine-Tuned
#             pred_ft, target_ft = infer_semantic(
#                 imgs[j],
#                 targets[j],
#                 model,
#                 target_size=target_img_size
#             )
#             hist_finetuned += fast_hist(target_ft.flatten(), pred_ft.flatten(), num_eval_classes)

# # --- STEP B: CARICAMENTO DEI PESI COCO ORIGINALI (SURGERY IN RAM) ---
# print("\n🔄 Sostituzione chirurgica dei pesi in memoria con COCO originale...")
# # Carichiamo lo state_dict originale di COCO nel modello attuale, sovrascrivendolo
# checkpoint_coco = torch.load(state_dict_path, map_location="cpu")
# if "state_dict" in checkpoint_coco:
#     # Usiamo strict=False perché la class_head originale di COCO ha dimensioni diverse
#     model.load_state_dict(checkpoint_coco["state_dict"], strict=False)

# # Pulizia immediata della cache per evitare crash di RAM
# del checkpoint_coco
# gc.collect()
# torch.cuda.empty_cache()

# # --- STEP C: VALUTAZIONE CON IL MODELLO COCO PURO ---
# print(f"📊 Fase 2: Valutazione in corso con il modello COCO PURO su {len(val_loader.dataset)} immagini...")

# model.eval()
# with torch.no_grad():
#     for batch in tqdm(val_loader, desc="COCO Pure Evaluation"):
#         imgs, targets = batch

#         for j in range(imgs.shape[0]):
#             # Inferenza con il modello riportato a COCO (la testa è resettata/casuale)
#             pred_coco, target_coco = infer_semantic(
#                 imgs[j],
#                 targets[j],
#                 model,
#                 target_size=target_img_size
#             )
#             hist_coco += fast_hist(target_coco.flatten(), pred_coco.flatten(), num_eval_classes)

# # =====================================================================
# # 2. CALCOLO DEI RISULTATI FINALI (IoU e mIoU)
# # =====================================================================
# ious_finetuned = per_class_iu(hist_finetuned)
# miou_finetuned = np.nanmean(ious_finetuned)

# ious_coco = per_class_iu(hist_coco)
# miou_coco = np.nanmean(ious_coco)

# # Classi ufficiali Cityscapes
# classes = [
#     "road", "sidewalk", "building", "wall", "fence", "pole", "traffic light",
#     "traffic sign", "vegetation", "terrain", "sky", "person", "rider", "car",
#     "truck", "bus", "train", "motorcycle", "bicycle"
# ]

# # =====================================================================
# # 3. VISUALIZZAZIONE TABELLA COMPARATIVA CONSOLIDATA
# # =====================================================================
# print("\n" + "="*65)
# print(f"{'CLASSE CITYSCAPES':<22} | {'IoU COCO %':<15} | {'IoU FINE-TUNED %':<15} | {'Δ Diff':<10}")
# print("-" * 65)

# for name, iou_cc, iou_ft in zip(classes, ious_coco, ious_finetuned):
#     cc_p = iou_cc * 100
#     ft_p = iou_ft * 100
#     diff = ft_p - cc_p
#     print(f"{name:<22} | {cc_p:>12.2f}% | {ft_p:>14.2f}% | {diff:>+7.2f}%")

# print("-" * 65)
# print(f"{'MEAN IoU GLOBAL':<22} | {miou_coco*100:>12.2f}% | {miou_finetuned*100:>14.2f}% | {(miou_finetuned-miou_coco)*100:>+7.2f}%")
# print("="*65)
# Out:
# 📊 Fase 1: Valutazione in corso con il modello FINE-TUNED su 500 immagini...
# Fine-tuned Evaluation:   0%|          | 0/250 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2252/3422945242.py in <cell line: 0>()
#      44         for j in range(len(imgs)): # Fixed: Changed imgs.shape[0] to len(imgs)
#      45             # Inferenza con il modello Fine-Tuned
# ---> 46             pred_ft, target_ft = infer_semantic(
#      47                 imgs[j],
#      48                 targets[j],
#
# /tmp/ipykernel_2252/1326802745.py in infer_semantic(img, target, model, target_size)
#      17
#      18         # Forward pass (restituisce liste di logit per ogni layer)
# ---> 19         mask_logits_layers, class_logits_layers = model(crops)
#      20
#      21         # Prendiamo l'output dell'ultimo blocco del decoder
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /content/MaskArchitectureAnomaly_CourseProject/eomt/training/lightning_module.py in forward(self, imgs)
#     172         x = imgs / 255.0
#     173
# --> 174         return self.network(x)
#     175
#     176     def training_step(self, batch, batch_idx):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /content/MaskArchitectureAnomaly_CourseProject/eomt/models/eomt.py in forward(self, x)
#     155             rope = self.encoder.backbone.rope_embeddings(x)
#     156
# --> 157         x = self.encoder.backbone.patch_embed(x)
#     158
#     159         if hasattr(self.encoder.backbone, "_pos_embed"):
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.12/dist-packages/timm/layers/patch_embed.py in forward(self, x)
#     129             pad_w = (self.patch_size[1] - W % self.patch_size[1]) % self.patch_size[1]
#     130             x = F.pad(x, (0, pad_w, 0, pad_h))
# --> 131         x = self.proj(x)
#     132         if self.flatten:
#     133             x = x.flatten(2).transpose(1, 2)  # NCHW -> NLC
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1749             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750         else:
# -> 1751             return self._call_impl(*args, **kwargs)
#    1752
#    1753     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1760                 or _global_backward_pre_hooks or _global_backward_hooks
#    1761                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762             return forward_call(*args, **kwargs)
#    1763
#    1764         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# RuntimeError: Input type (torch.cuda.HalfTensor) and weight type (torch.HalfTensor) should be the same

# %%
# import numpy as np
# from tqdm import tqdm

# # Funzioni di calcolo (rimangono invariate nella logica)
# def fast_hist(a, b, n):
#     k = (a >= 0) & (a < n) & (b >= 0) & (b < n)
#     return np.bincount(n * a[k].astype(int) + b[k], minlength=n**2).reshape(n, n)

# def per_class_iu(hist):
#     return np.diag(hist) / (np.maximum(1.0, hist.sum(1) + hist.sum(0) - np.diag(hist)))

# # 1. Preparazione
# num_eval_classes = 19
# hist = np.zeros((num_eval_classes, num_eval_classes))
# val_loader = data.val_dataloader()

# print(f"Inizio valutazione su {len(val_loader.dataset)} immagini...")

# # 2. Ciclo di valutazione
# model.eval()
# with torch.no_grad():
#     for batch in tqdm(val_loader):
#         imgs, targets = batch # In CityscapesSemantic solitamente sono tensori

#         # Iteriamo sul batch (es. batch_size=2)
#         for j in range(imgs.shape[0]):
#             # Eseguiamo l'inferenza (usando la versione corretta della funzione)
#             pred_array, target_array = infer_semantic(
#                 imgs[j],
#                 targets[j],
#                 model,
#                 target_size=target_img_size
#             )

#             # Aggiorniamo la matrice di confusione
#             hist += fast_hist(target_array.flatten(), pred_array.flatten(), num_eval_classes)

# # 3. Calcolo Risultati
# ious = per_class_iu(hist)
# miou = np.nanmean(ious)

# # Classi ufficiali Cityscapes
# classes = [
#     "road", "sidewalk", "building", "wall", "fence", "pole", "traffic light",
#     "traffic sign", "vegetation", "terrain", "sky", "person", "rider", "car",
#     "truck", "bus", "train", "motorcycle", "bicycle"
# ]

# # 4. Visualizzazione Tabella
# print("\n" + "="*40)
# print(f"{'CLASSE':<20} | {'IoU %':<10}")
# print("-" * 35)
# for name, iou in zip(classes, ious):
#     print(f"{name:<20} | {iou*100:>8.2f}%")
# print("-" * 35)
# print(f"{'MEAN IoU':<20} | {miou*100:>8.2f}%")
# print("="*40)

# %%
#parte vecchia

# %% [markdown]
# ## Load model

# %%
# warnings.filterwarnings(
#     "ignore",
#     message=r".*Attribute 'network' is an instance of `nn\.Module` and is already saved during checkpointing.*",
# )

# # Load encoder
# encoder_cfg = current_config["model"]["init_args"]["network"]["init_args"]["encoder"]#
# encoder_module_name, encoder_class_name = encoder_cfg["class_path"].rsplit(".", 1)#
# encoder_cls = getattr(importlib.import_module(encoder_module_name), encoder_class_name)#
# encoder = encoder_cls(img_size=target_img_size, **encoder_cfg.get("init_args", {}))#

# # Load network
# network_cfg = current_config["model"]["init_args"]["network"]
# network_module_name, network_class_name = network_cfg["class_path"].rsplit(".", 1)
# network_cls = getattr(importlib.import_module(network_module_name), network_class_name)
# network_kwargs = {k: v for k, v in network_cfg["init_args"].items() if k != "encoder"}
# network = network_cls(
#     masked_attn_enabled=False,
#     num_classes=num_classes_final,
#     encoder=encoder,
#     **network_kwargs,
# )

# # Load Lightning module
# lit_module_name, lit_class_name = current_config["model"]["class_path"].rsplit(".", 1)
# lit_cls = getattr(importlib.import_module(lit_module_name), lit_class_name)
# model_kwargs = {k: v for k, v in current_config["model"]["init_args"].items() if k != "network"}

# if "stuff_classes" in current_config["data"].get("init_args", {}):
#     model_kwargs["stuff_classes"] = current_config["data"]["init_args"]["stuff_classes"]

# %% [markdown]
# ## Load pre-trained weights from Hugging Face Hub
# The model weights are downloaded from the Hugging Face Hub using the logger name from the config. Make sure you have a working internet connection.

# %%
# # Ripuliamo i kwargs new
# model_kwargs_final = {k: v for k, v in current_config["model"]["init_args"].items() if k != "network"}
# model_kwargs_final.pop("num_classes", None) # Rimuoviamo per non avere sovrascritture
# model_kwargs_final.pop("img_size", None)

# # FIX CRUCIALE: Rimuoviamo eventuali 'num_classes' dai kwargs che potrebbero sovrascrivere il nostro valore
# # if "num_classes" in model_kwargs_final:
# #   del model_kwargs_final["num_classes"]

# # new
# if "stuff_classes" in current_config["data"].get("init_args", {}):
#     model_kwargs_final["stuff_classes"] = current_config["data"]["init_args"]["stuff_classes"]

# name = current_config.get("trainer", {}).get("logger", {}).get("init_args", {}).get("name")
# is_dinov3 = "dinov3" in name if name else False

# if is_dinov3:
#     model_kwargs["ckpt_path"] = state_dict_path
#     model_kwargs["delta_weights"] = True

# model = (
#     lit_cls(
#         img_size=target_img_size,
#         num_classes=num_classes_final,
#         network=network,
#         **model_kwargs_final,
#     )
#     .to(device)
# )

# %% [markdown]
# ## Transfer Learning and Fine Tuning

# %%
# if not is_dinov3:
#     state_dict = torch.load(state_dict_path, map_location=f"cuda:{device}", weights_only=True)

#     # Freeze all, only unlock the head
#     keys_to_delete = [
#               "network.class_head.weight",
#               "network.class_head.bias",
#               "criterion.empty_weight"
#           ]
#     for key in keys_to_delete:
#         if key in state_dict:
#             del state_dict[key]

# model.load_state_dict(state_dict, strict=False)

# %%
# for param in model.parameters():
#     param.requires_grad = False

# for param in model.network.class_head.parameters():
#     param.requires_grad = True

# # if hasattr(model.network, 'transformer_decoder'):
# #     for param in model.network.transformer_decoder.layers[-1].parameters():
# #         param.requires_grad = True

# # print(f"Parametri addestrabili: {sum(p.numel() for p in model.parameters() if p.requires_grad)}")

# # checkpoint
# checkpoint_callback = ModelCheckpoint(
#   dirpath="/content/drive/MyDrive/CourseProjectAnomaly/checkpoints", # folder for saving
#   filename="coco-finetuned-cityscapes-{epoch:02d}", # file name
#   save_last=True, # always save last epoch
#   save_top_k=1,
#   monitor="metrics/val_iou_all",
#   mode="max"
# )

# # fine tuning dei parametri sbloccati
# trainer = L.Trainer(
#     max_epochs=5,              # 10 Numero epoche suggerito
#     accelerator="gpu",


#     limit_train_batches=0.05, # Usa solo il 5% dei dati
#     limit_val_batches=0.05,   # Valida solo sul 5%


#     devices=1,
#     precision="16-mixed",       # tip del progetto
#     callbacks=[checkpoint_callback],
#     log_every_n_steps=10,
#     #logger=wandb_logger,
#     default_root_dir="/content/drive/MyDrive/CourseProjectAnomaly/checkpoints"
# )

# # Avvio Fine-tuning
# trainer.fit(model, datamodule=data)

# %%
# ### aggiunta per inviare i risultati visuali alla dashboard online

# # 1. Recupera un'immagine dal set di validazione
# img_val, target_val = data.val_dataloader().dataset[img_idx]

# # 2. Esegui l'inferenza usando la funzione definita prima
# pred_array, target_array = infer_semantic(img_val, target_val)

# # 3. Prepara le versioni colorate per la visualizzazione
# mapping = create_mapping([pred_array, target_array], IGNORE_INDEX)
# pred_colored = apply_colormap(pred_array, mapping)
# target_colored = apply_colormap(target_array, mapping)

# # 4. Denormalizza l'immagine originale per WandB (se necessario)
# # Questo serve per evitare che l'immagine originale appaia troppo scura o strana
# img_input = img_val.permute(1, 2, 0).cpu().numpy()
# if img_input.max() > 1.0 or img_input.min() < 0:
#     img_input = (img_input - img_input.min()) / (img_input.max() - img_input.min())

# # 5. Logga finalmente su WandB
# wandb_logger.log_image(
#     key="final_results",
#     images=[img_input, pred_colored, target_colored],
#     caption=["Original Image", "Model Prediction", "Ground Truth"]
# )

# %% [markdown]
# ## Semantic inference (pixel-wise classification)
#
# > This inference method also works when applied to a model trained for panoptic segmentation.
#
# Semantic inference computes per-pixel class scores by combining mask and class predictions:
#
# $$
# \sum_i p_i(c) \cdot m_i[h, w]
# $$
#
# Here, $p_i(c)$ is the class probability for class $c$ (excluding "no object"), and $m_i[h, w]$ is the sigmoid-normalized mask value for query $i$ at pixel $(h, w)$. The final class is selected by taking the argmax over classes.
#
# *This inference method was originally introduced in MaskFormer.*

# %%
# def infer_semantic(img, target):
#     model.eval()
#     model.to(device) # aggiunto per riportare in GPU
#     model.network.encoder.to(device) # aggiunto per riportare in GPU

#     # aggiunto Sposta l'immagine sul dispositivo del modello (GPU)
#     img = img.to(device)

#     # FIX  PER LE FINESTRE
#     # Forza il modello a usare la dimensione della finestra corretta
#     # (640 per COCO, 1024 per Cityscapes)
#     model.window_size = target_img_size[0]

#     with torch.no_grad(), autocast(dtype=torch.float16, device_type="cuda"):
#         imgs = [img.to(device)]
#         img_sizes = [img.shape[-2:] for img in imgs]
#         crops, origins = model.window_imgs_semantic(imgs)

#         mask_logits_per_layer, class_logits_per_layer = model(crops)
#         mask_logits = F.interpolate(
#             mask_logits_per_layer[-1], target_img_size, mode="bilinear"
#         )

#         crop_logits = model.to_per_pixel_logits_semantic(
#             mask_logits, class_logits_per_layer[-1]
#         )
#         logits = model.revert_window_logits_semantic(crop_logits, origins, img_sizes)
#         preds = logits[0].argmax(0).cpu()

#     pred_array = preds.numpy()

#     target_array = model.to_per_pixel_targets_semantic([target], IGNORE_INDEX)[0].numpy()
#     return pred_array, target_array


# def plot_semantic_results(img, pred_array, target_array):
#     mapping = create_mapping([pred_array, target_array], IGNORE_INDEX)

#     fig, axes = plt.subplots(1, 3, figsize=(15, 5))

#     # Gestione dell'immagine (se normalizzata o meno)
#     img_np = img.permute(1, 2, 0).cpu().numpy()
#     # Se i valori sono fuori dal range [0,1], normalizziamo per la visualizzazione
#     if img_np.max() > 1.0 or img_np.min() < 0:
#         img_np = (img_np - img_np.min()) / (img_np.max() - img_np.min())

#     axes[0].imshow(img.permute(1, 2, 0).cpu().numpy())
#     axes[0].set_title("Image")
#     axes[1].imshow(apply_colormap(pred_array, mapping))
#     axes[1].set_title("Prediction")
#     axes[2].imshow(apply_colormap(target_array, mapping))
#     axes[2].set_title("Target")

#     for ax in axes:
#         ax.axis("off")

#     plt.tight_layout()
#     plt.show()

# %%
# # run for the cityscapes pre-trained model
# img_cs, target_cs = data.val_dataloader().dataset[img_idx]
# pred_array_cs, target_array_cs = infer_semantic(img_cs, target_cs)
# plot_semantic_results(img_cs, pred_array_cs, target_array_cs)

# %%
# # run for the coco pre-trained model
# img_cc, target_cc = data.val_dataloader().dataset[img_idx]
# pred_array_cc, target_array_cc = infer_semantic(img_cc, target_cc)
# plot_semantic_results(img_cc, pred_array_cc, target_array_cc)

# %% [markdown]
# ## Evaluation
# Consistent evaluation strategy that allows fair comparison across both models for the semantic segmentation task

# %%
# import numpy as np
# from tqdm import tqdm

# def fast_hist(a, b, n):
#     """
#     Calcola la matrice di confusione.
#     a: ground truth (target), b: predizione, n: numero di classi
#     """
#     k = (a >= 0) & (a < n) & (b >= 0) & (b < n) # Modifica qui: filtra anche b
#     return np.bincount(n * a[k].astype(int) + b[k], minlength=n**2).reshape(n, n)

# def per_class_iu(hist):
#     """Calcola la IoU per ogni classe dalla matrice di confusione."""
#     return np.diag(hist) / (hist.sum(1) + hist.sum(0) - np.diag(hist))

# # setting
# num_eval_classes = 19 # Cityscapes ha 19 classi di valutazione
# hist = np.zeros((num_eval_classes, num_eval_classes))
# val_loader = data.val_dataloader()

# print(f"evaluation on {len(val_loader)} images...")
# print(f"Current model: {'COCO' if use_coco else 'Cityscapes'}")

# # evaluation, modificato per batch_size > 1
# for i, batch in enumerate(tqdm(val_loader)):
#     # Estraiamo le liste di immagini e target dal batch
#     # batch[0] è la lista delle immagini, batch[1] è la lista dei target
#     imgs_in_batch = batch[0]
#     targets_in_batch = batch[1]

#     # Iteriamo su ogni singolo elemento all'interno del batch (nel tuo caso, 2 iterazioni)
#     for j in range(len(imgs_in_batch)):
#         img = imgs_in_batch[j]
#         target = targets_in_batch[j]

#         # Eseguiamo l'inferenza semantica (include la mappatura se use_coco=True)
#         pred_array, target_array = infer_semantic(img, target)

#         # Aggiorniamo la matrice di confusione
#         hist += fast_hist(target_array.flatten(), pred_array.flatten(), num_eval_classes)

# # calcolo finale
# ious = per_class_iu(hist)
# miou = np.nanmean(ious)

# # visualization results
# classes = [
#     "road", "sidewalk", "building", "wall", "fence", "pole", "traffic light",
#     "traffic sign", "vegetation", "terrain", "sky", "person", "rider", "car",
#     "truck", "bus", "train", "motorcycle", "bicycle"
# ]

# print("\n" + "="*30)
# print(f"Results MIOU - {'COCO' if use_coco else 'CITYSCAPES'}")
# print("="*30)
# for name, iou in zip(classes, ious):
#     print(f"{name:15}: {iou*100:6.2f}%")
# print("-" * 30)
# print(f"MEAN IoU: {miou*100:6.2f}%")
# print("="*30)
